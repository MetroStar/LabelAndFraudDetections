# %%
import pandas as pd
pd.options.display.max_columns = 500
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_csv("all_drinks.csv")
raw_data.head(10)
# Out:
#    Unnamed: 0                              strDrink         dateModified  \
# 0           0  '57 Chevy with a White License Plate  2016-07-18 22:49:04
# 1           1                        1-900-FUK-MEUP  2016-07-18 22:27:04
# 2           2                      110 in the shade  2016-02-03 14:51:57
# 3           3                151 Florida Bushwacker  2016-07-18 22:28:43
# 4           4                           155 Belmont  2016-10-05 12:36:28
# 5           5                         24k nightmare  2016-07-18 22:31:38
# 6           6                                   252  2016-07-18 22:32:42
# 7           7                            3 Wise Men  2016-07-18 22:34:37
# 8           8           3-Mile Long Island Iced Tea  2016-08-31 19:42:52
# 9           9                              410 Gone  2016-08-31 19:43:46
#
#    idDrink strAlcoholic           strCategory  \
# 0    14029    Alcoholic              Cocktail
# 1    15395    Alcoholic                  Shot
# ...

# %%
raw_data["Ingredient1"] = raw_data["strMeasure1"].map(str) + " " + raw_data["strIngredient1"]
raw_data["Ingredient2"] = raw_data["strMeasure2"].map(str) + " " + raw_data["strIngredient2"]
raw_data["Ingredient3"] = raw_data["strMeasure3"].map(str) + " " + raw_data["strIngredient3"]
raw_data["Ingredient4"] = raw_data["strMeasure4"].map(str) + " " + raw_data["strIngredient4"]
raw_data["Ingredient5"] = raw_data["strMeasure5"].map(str) + " " + raw_data["strIngredient5"]
raw_data["Ingredient6"] = raw_data["strMeasure6"].map(str) + " " + raw_data["strIngredient6"]
raw_data["Ingredient7"] = raw_data["strMeasure7"].map(str) + " " + raw_data["strIngredient7"]
raw_data["Ingredient8"] = raw_data["strMeasure8"].map(str) + " " + raw_data["strIngredient8"]
raw_data["Ingredient9"] = raw_data["strMeasure9"].map(str) + " " + raw_data["strIngredient9"]
raw_data["Ingredient10"] = raw_data["strMeasure10"].map(str) + " " + raw_data["strIngredient10"]
raw_data["Ingredient11"] = raw_data["strMeasure11"].map(str) + " " + raw_data["strIngredient11"]
raw_data["Ingredient12"] = raw_data["strMeasure12"].map(str) + " " + raw_data["strIngredient12"]
raw_data["Ingredient13"] = raw_data["strMeasure13"].map(str) + " " + raw_data["strIngredient13"]
raw_data["Ingredient14"] = raw_data["strMeasure14"].map(str) + " " + raw_data["strIngredient14"]
raw_data["Ingredient15"] = raw_data["strMeasure15"].map(str) + " " + raw_data["strIngredient15"]
raw_data.head(50)
# Out:
#     Unnamed: 0                              strDrink         dateModified  \
# 0            0  '57 Chevy with a White License Plate  2016-07-18 22:49:04
# 1            1                        1-900-FUK-MEUP  2016-07-18 22:27:04
# 2            2                      110 in the shade  2016-02-03 14:51:57
# 3            3                151 Florida Bushwacker  2016-07-18 22:28:43
# 4            4                           155 Belmont  2016-10-05 12:36:28
# 5            5                         24k nightmare  2016-07-18 22:31:38
# 6            6                                   252  2016-07-18 22:32:42
# 7            7                            3 Wise Men  2016-07-18 22:34:37
# 8            8           3-Mile Long Island Iced Tea  2016-08-31 19:42:52
# 9            9                              410 Gone  2016-08-31 19:43:46
# 10          10                                 50/50  2016-04-29 09:41:56
# 11          11                              501 Blue  2016-04-28 19:11:37
# ...
